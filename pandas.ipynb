# %%
import pandas as pd

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Age': [25, 30, 35, 40, 45],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix']
}

df = pd.DataFrame(data)
df

# %%
print(df['City'])

# %%
print(df['Age'].max())

# %%
data1 = pd.Series([1,2,3,4,5])
print(data1)

# %%
cars = pd.read_csv("car_data.csv")
print(cars)

# %%
cars.dtypes

# %%
cars.info()

# %%
print(cars[["Make","Model","Year","Max Power","Price"]])

# %%
print(cars[cars["Price"] < 505000])
